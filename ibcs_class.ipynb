# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np

# %%
from ibcspy import Ibcs

# %%
data= np.array([
    [50,100,75,70,35,35,80,105,40,55],
    [45,85,60, 65,60,40,60,95,75,65]
])


dates = np.arange(2009,2019,1)

# %%
args = [data,dates]
kwargs = {
         'offset'  : 1
        ,'factor' : 3
        ,'t_gr'   : 3
        ,'m_gr'   : 1
        ,'l_gr'   : 0
        ,'b_gr'   : 0
        ,'label_offset' : 3
        ,'label_normalize' : 1
        ,'axis_pad' : 10
        ,'cap_perc' : 0.5
        ,'label_space':2
    }

# %%
kwargs
# Out:
# {'offset': 1,
#  'factor': 3,
#  't_gr': 3,
#  'm_gr': 1,
#  'l_gr': 0,
#  'b_gr': 0,
#  'label_offset': 3,
#  'label_normalize': 1,
#  'axis_pad': 10,
#  'cap_perc': 0.5,
#  'label_space': 2}

# %%
data
# Out:
# array([[ 50, 100,  75,  70,  35,  35,  80, 105,  40,  55],
#        [ 45,  85,  60,  65,  60,  40,  60,  95,  75,  65]])

# %%
plt.rcParams['figure.figsize'] = [15, 10]

i = Ibcs()
i.ibcs_barchart(data,dates,**kwargs)
